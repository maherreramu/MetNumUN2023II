# %% [markdown]
# <a href="https://colab.research.google.com/github/maherreramu/MetNumUN2023II/blob/main/maherreramuLab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## ID digit: 3

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# - (x-9)(x-7)(x-4)(x-12)(x-2)(x+1)(x-11)(x+15)(x+8)(x-3) = x^10 - 24 x^9 - 69 x^8 + 6150 x^7 - 47385 x^6 - 107844 x^5 + 2798429 x^4 - 12121290 x^3 + 16637184 x^2 + 7661088 x - 23950080
#
# - (x^10 - 24 x^9 - 69 x^8 + 6150 x^7 - 47385 x^6 - 107844 x^5 + 2798429 x^4 - 12121290 x^3 + 16637184 x^2 + 7661088 x - 23950080)/(x-3) = (x + 1) (x - 2) (x - 4) (x - 7) (x + 8) (x - 9) (x - 11) (x - 12) (x + 15) (para x!=3)

# %% [markdown]
# **Polynomial degree 10**
#
# ![image.png](data:image/png;base64,...)
#
# **Polynomial divided by a root**
#
# ![image.png](data:image/png;base64,...)
#
# **Polynomial divided by a not root**
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 - 24*x**9 - 69*x**8 + 6150*x**7 - 47385*x**6 - 107844*x**5 + 2798429*x**4 - 12121290*x**3 + 16637184*x**2 + 7661088*x - 23950080

p, r = div(p,  x-9)

print(p)
print(r)

p, r = div(p,  x-7)

print(p)
print(r)

p, r = div(p,  x-4)

print(p)
print(r)

p, r = div(p,  x-12)

print(p)
print(r)

p, r = div(p,  x-2)

print(p)
print(r)

p, r = div(p,  x+1)

print(p)
print(r)

p, r = div(p,  x-11)

print(p)
print(r)

p, r = div(p,  x+15)

print(p)
print(r)

p, r = div(p,  x+8)

print(p)
print(r)

p, r = div(p,  x-3)

print(p)
print(r)
# Out:
# x**9 - 15*x**8 - 204*x**7 + 4314*x**6 - 8559*x**5 - 184875*x**4 + 1134554*x**3 - 1910304*x**2 - 555552*x + 2661120
# 0
# x**8 - 8*x**7 - 260*x**6 + 2494*x**5 + 8899*x**4 - 122582*x**3 + 276480*x**2 + 25056*x - 380160
# 0
# x**7 - 4*x**6 - 276*x**5 + 1390*x**4 + 14459*x**3 - 64746*x**2 + 17496*x + 95040
# 0
# x**6 + 8*x**5 - 180*x**4 - 770*x**3 + 5219*x**2 - 2118*x - 7920
# 0
# x**5 + 10*x**4 - 160*x**3 - 1090*x**2 + 3039*x + 3960
# 0
# x**4 + 9*x**3 - 169*x**2 - 921*x + 3960
# 0
# x**3 + 20*x**2 + 51*x - 360
# 0
# x**2 + 5*x - 24
# 0
# x - 3
# 0
# 1
# 0

# %%
p = x**10 - 24*x**9 - 69*x**8 + 6150*x**7 - 47385*x**6 - 107844*x**5 + 2798429*x**4 - 12121290*x**3 + 16637184*x**2 + 7661088*x - 23950080

p, r = div(p,  x-13)

print(p)
print(r)
# Out:
# x**9 - 11*x**8 - 212*x**7 + 3394*x**6 - 3263*x**5 - 150263*x**4 + 845010*x**3 - 1136160*x**2 + 1867104*x + 31933440
# 391184640

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x**10 - 24*x**9 - 69*x**8 + 6150*x**7 - 47385*x**6 - 107844*x**5 + 2798429*x**4 - 12121290*x**3 + 16637184*x**2 + 7661088*x - 23950080)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 24*x**9 - 69*x**8 + 6150*x**7 - 47385*x**6 - 107844*x**5 + 2798429*x**4 - 12121290*x**3 + 16637184*x**2 + 7661088*x - 23950080)
# Out:
# (x - 12)*(x - 11)*(x - 9)*(x - 7)*(x - 4)*(x - 3)*(x - 2)*(x + 1)*(x + 8)*(x + 15)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - x**10 - 24*x**9 - 69*x**8 + 6150*x**7 - 47385*x**6 - 107844*x**5 + 2798429*x**4 - 12121290*x**3 + 16637184*x**2 + 7661088*x - 23950080 = 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 24*x**9 - 69*x**8 + 6150*x**7 - 47385*x**6 - 107844*x**5 + 2798429*x**4 - 12121290*x**3 + 16637184*x**2 + 7661088*x - 23950080, 0), x)
# Out:
# {-15, -8, -1, 2, 3, 4, 7, 9, 11, 12}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, GoldenRatio, E, pi
phi = GoldenRatio
x = Symbol('x')
solveset(Eq(x**2 * phi - (sqrt(3)+E)*x + (sqrt(7)-pi), 0), x)
# Out:
# {(sqrt(3) + E)/(2*GoldenRatio) + sqrt(4*GoldenRatio*(pi - sqrt(7)) + (sqrt(3) + E)**2)/(2*GoldenRatio), -sqrt(4*GoldenRatio*(pi - sqrt(7)) + (sqrt(3) + E)**2)/(2*GoldenRatio) + (sqrt(3) + E)/(2*GoldenRatio)}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 24*x**9 - 69*x**8 + 6150*x**7 - 47385*x**6 - 107844*x**5 + 2798429*x**4 - 12121290*x**3 + 16637184*x**2 + 7661088*x - 23950080, domain='GF(3)')
# Out:
# x**4*(x - 1)**3*(x + 1)**3

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + 2+I*y2, z = z1 + 3+I*z2, x - y * z

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = x1 + I*x2
y = y1 + 2+I*y2
z = z1 + 3+I*z2

print(x-y*z)
print(expand(x-y*z))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# x1 + I*x2 - (y1 + I*y2 + 2)*(z1 + I*z2 + 3)
# x1 + I*x2 - y1*z1 - I*y1*z2 - 3*y1 - I*y2*z1 + y2*z2 - 3*I*y2 - 2*z1 - 2*I*z2 - 6
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Santa Marta in December?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, cos
x = Symbol('x')
integrate(pi**(-x)*cos(x), x)
# Out:
# sin(x)/(pi**x + pi**x*log(pi)**2) - log(pi)*cos(x)/(pi**x + pi**x*log(pi)**2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**2 * sin(x)**3, (x,-2,10))
# Out:
# 40*sin(10)*cos(10)**2/3 + 140*sin(10)**3/9 - 28*sin(2)**3/9 + 22*sin(2)**2*cos(2)/9 - 8*sin(2)*cos(2)**2/3 + 32*cos(2)**3/27 - 886*sin(10)**2*cos(10)/9 - 1760*cos(10)**3/27

# %%
from sympy import Symbol, integrate, sin, N, cos, E
x = Symbol('x')
N(integrate(E**(cos(x))*sin(x), (x,E,10)))
# Out:
# -0.0302846541683981
